# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Running cells with 'venv (3.13.4.final.0) (Python 3.13.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ASUS/OneDrive/Desktop/AIproject/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
